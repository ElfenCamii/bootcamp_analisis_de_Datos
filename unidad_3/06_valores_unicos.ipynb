# %%
import pandas as pd
import numpy as np
df_olx_medallo = pd.read_csv("C:/Users/PC/Documents/cursos/Bootcamp analisis datos/archivos_data/olx_medellin.csv")

# %% [markdown]
# Valores únicos

# %%
# Quiero conocer los valores unicos
df_olx_medallo['color'].unique

# Quiero conocer la cantidad de los valores
df_olx_medallo.nunique()
# Out:
# marca                35
# linea               200
# modelo               43
# condición             2
# combustible           4
# color                15
# transmisión           3
# único_dueño           2
# tipo_de_vendedor      2
# kilometraje         535
# puertas               5
# precio              324
# dtype: int64

# %% [markdown]
# Ordenamiento

# %%
df_olx_medallo.sort_values('modelo', ascending=False)

###
# Ejemplo 1:
# Seleccionar autos de modelos entre 2010 y 2020 incluidos y ordenades de manera descendente por su precio
###

df_modelos = df_olx_medallo[(df_olx_medallo['modelo'] >= 2010) & (df_olx_medallo['modelo'] <= 2020)]
df_modelos = df_modelos.sort_values(by="precio", ascending=False)            # Para ordenar la salida de manera desendente o ascendente
df_modelos

### Ordenar con dos columnas

df_olx_medallo.sort_values(['modelo', 'kilometraje'], ascending=[False, True])
# Out:
#            marca       linea  modelo condición combustible   color  \
# 1088      Toyota       LC200    2020     Nuevo      Diesel  Blanco
# 774          Kia    Sportage    2020     Usado    Gasolina    Gris
# 222        Mazda           3    2020     Usado    Gasolina  Blanco
# 1084     Renault       Logan    2020     Usado    Gasolina    Gris
# 147      Renault     Sandero    2020     Usado    Gasolina   Beige
# ...          ...         ...     ...       ...         ...     ...
# 122         Ford      Ranger    1970     Usado    Gasolina    Azul
# 957       Toyota  FJ Cruiser    1970     Usado    Gasolina    Azul
# 1052  Volkswagen  Escarabajo    1966     Usado    Gasolina   Beige
# 163        Buick     Century    1966     Usado    Gasolina   Negro
# 566         Ford       F-100    1963     Usado    Gasolina    Rojo
#
#                 transmisión único_dueño      tipo_de_vendedor  kilometraje  \
# 1088             Automática          Sí  Vendedor Profesional            0
# ...
